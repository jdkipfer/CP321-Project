# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binned_statistic
df=pd.read_csv('data/2013-2014.csv',sep=',')

print(df.columns)
# Out:
# Index(['Number', 'Race', 'Race Grouping', 'Gender', 'Age',
#        'In Custody/Community', 'Supervision Type', 'Jurisdiction',
#        'Sentence Type', 'Aggregate Sentence Length',
#        'Institutional Security Level', 'Province', 'Location Type',
#        'Offender Security Level', 'Dynamic/Need', 'Static/Risk',
#        'Reintegration Potential', 'Motivation', 'Major Offence Group',
#        'Religion'],
#       dtype='object')

# %%
ax = df['Age'].plot.hist(bins=25, rwidth=0.9)
plt.xlabel('Age',fontsize='13')
plt.show()

# %%
dfH=filtered[(filtered['Major Offence Group']=='2019-01-01') & (filtered['Date']<='2019-12-31')]
ax = df['Age'].plot.hist(bins=25, rwidth=0.9)

filtered=filtered[(filtered['Date']>='2019-01-01') & (filtered['Date']<='2019-12-31')]
plt.xlabel('Age',fontsize='13')
plt.show()

# %%
import numpy as np 
import pylab 
import scipy.stats as stats

measurements = np.random.normal(loc = 30, scale = 3, size=100)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()
